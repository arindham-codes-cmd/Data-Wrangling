# %%
# importing libraries
import pandas as pd
import numpy

# %%
df = pd.read_excel(r'C:\Users\Arindham Krishna\Desktop\Data Engineer MIT\Data Sets\bglrprice\TestBHP.xlsx')

# %%
# df.info()

# %%
# df.describe()

# %%
df.head(10)
# Out:
#               area_type         availability                  location  \
# 0  Super built-up  Area  2025-12-19 00:00:00  Electronic City Phase II
# 1            Plot  Area        Ready To Move          Chikka Tirupathi
# 2        Built-up  Area        Ready To Move               Uttarahalli
# 3  Super built-up  Area        Ready To Move        Lingadheeranahalli
# 4  Super built-up  Area        Ready To Move                  Kothanur
# 5  Super built-up  Area        Ready To Move                Whitefield
# 6  Super built-up  Area  2025-05-18 00:00:00          Old Airport Road
# 7  Super built-up  Area        Ready To Move              Rajaji Nagar
# 8  Super built-up  Area        Ready To Move              Marathahalli
# 9            Plot  Area        Ready To Move              Gandhi Bazar
#
#         size  society total_sqft  bath  balcony   price  price_1  price_1.1
# 0      2 BHK  Coomee        1056   2.0      1.0   39.07    39.07      39.07
# ...

# %%
# df.isnull().sum()
# Out:
# area_type        0
# availability     0
# location         0
# size             0
# society         42
# total_sqft       0
# bath             2
# balcony          8
# price            0
# price_1          6
# price_1.1       17
# dtype: int64

# %%
# fillna()
df['balcony'] = df['balcony'].fillna(0)

# %%
# df.head(10)
# Mean (Average) → Best for normally distributed numerical data
# Median → Best for skewed data with outliers
# Mode → Best for categorical data
# Out:
#               area_type         availability                  location  \
# 0  Super built-up  Area  2025-12-19 00:00:00  Electronic City Phase II
# 1            Plot  Area        Ready To Move          Chikka Tirupathi
# 2        Built-up  Area        Ready To Move               Uttarahalli
# 3  Super built-up  Area        Ready To Move        Lingadheeranahalli
# 4  Super built-up  Area        Ready To Move                  Kothanur
# 5  Super built-up  Area        Ready To Move                Whitefield
# 6  Super built-up  Area  2025-05-18 00:00:00          Old Airport Road
# 7  Super built-up  Area        Ready To Move              Rajaji Nagar
# 8  Super built-up  Area        Ready To Move              Marathahalli
# 9            Plot  Area        Ready To Move              Gandhi Bazar
#
#         size  society total_sqft  bath  balcony   price  price_1  price_1.1
# 0      2 BHK  Coomee        1056   2.0      1.0   39.07    39.07      39.07
# ...

# %%
df['price_1'].fillna(df['price_1'].mean(), inplace=True)
df['price_1.1'].fillna(df['price_1.1'].median(), inplace=True)

# %%
df.head(10)
# Out:
#               area_type         availability                  location  \
# 0  Super built-up  Area  2025-12-19 00:00:00  Electronic City Phase II
# 1            Plot  Area        Ready To Move          Chikka Tirupathi
# 2        Built-up  Area        Ready To Move               Uttarahalli
# 3  Super built-up  Area        Ready To Move        Lingadheeranahalli
# 4  Super built-up  Area        Ready To Move                  Kothanur
# 5  Super built-up  Area        Ready To Move                Whitefield
# 6  Super built-up  Area  2025-05-18 00:00:00          Old Airport Road
# 7  Super built-up  Area        Ready To Move              Rajaji Nagar
# 8  Super built-up  Area        Ready To Move              Marathahalli
# 9            Plot  Area        Ready To Move              Gandhi Bazar
#
#         size  society total_sqft  bath  balcony   price     price_1  price_1.1
# 0      2 BHK  Coomee        1056   2.0      1.0   39.07   39.070000      39.07
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
df
# Out:
#                area_type         availability                   location  \
# 0   Super built-up  Area  2025-12-19 00:00:00   Electronic City Phase II
# 1             Plot  Area        Ready To Move           Chikka Tirupathi
# 2         Built-up  Area        Ready To Move                Uttarahalli
# 3   Super built-up  Area        Ready To Move         Lingadheeranahalli
# 4   Super built-up  Area        Ready To Move                   Kothanur
# 5   Super built-up  Area        Ready To Move                 Whitefield
# 6   Super built-up  Area  2025-05-18 00:00:00           Old Airport Road
# 7   Super built-up  Area        Ready To Move               Rajaji Nagar
# 8   Super built-up  Area        Ready To Move               Marathahalli
# 9             Plot  Area        Ready To Move               Gandhi Bazar
# 10  Super built-up  Area  2025-02-18 00:00:00                 Whitefield
# 11            Plot  Area        Ready To Move                 Whitefield
# ...

# %%
# dropna
df.dropna(subset=['society'],inplace = True)

# %%
df.isnull().sum()
# Out:
# area_type       0
# availability    0
# location        0
# size            0
# society         0
# total_sqft      0
# bath            2
# balcony         0
# price           0
# price_1         0
# price_1.1       0
# dtype: int64

# %%
# interpolate
# df['temp'] = df['temp'].interpolate(method='linear')
# df['temp'] = df['temp'].interpolate(method='polynomial', order = 2)
# df['sales'] = df['sales'].interpolate(method='time')

# %%
# Data type conversion
fin = pd.read_excel(r'C:\Users\Arindham Krishna\Desktop\Data Engineer MIT\Data Sets\Company Financial\TestFin.xlsx')

# %%
fin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Segment                30 non-null     object
#  1   Country                30 non-null     object
#  2    Product               30 non-null     object
#  3    Discount Band         30 non-null     object
#  4    Units Sold            30 non-null     object
#  5    Manufacturing Price   30 non-null     object
#  6    Sale Price            30 non-null     object
#  7    Gross Sales           30 non-null     object
#  8    Discounts             30 non-null     object
#  9     Sales                30 non-null     object
#  10   COGS                  30 non-null     object
#  11   Profit                30 non-null     object
#  12  Date                   30 non-null     datetime64[ns]
#  13  Month Number           30 non-null     int64
# ...

# %%
# fin.head(10)

# %%
# object to float
# fin['  Sales '] = fin['  Sales '].astype(float)

# %%
# fin.columns

# %%
# regex
# https://saturncloud.io/blog/how-to-apply-regex-to-a-pandas-dataframe/ 
# https://www.geeksforgeeks.org/python-regex-cheat-sheet/

# fin['  Sales '] = fin['  Sales '].str.replace('[\$,]', '', regex = True)

# %%
# fin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Segment                30 non-null     object
#  1   Country                30 non-null     object
#  2    Product               30 non-null     object
#  3    Discount Band         30 non-null     object
#  4    Units Sold            30 non-null     object
#  5    Manufacturing Price   30 non-null     object
#  6    Sale Price            30 non-null     object
#  7    Gross Sales           30 non-null     object
#  8    Discounts             30 non-null     object
#  9     Sales                30 non-null     object
#  10   COGS                  30 non-null     object
#  11   Profit                30 non-null     object
#  12  Date                   30 non-null     datetime64[ns]
#  13  Month Number           30 non-null     int64
# ...

# %%
# fin[' Discounts '] = pd.to_numeric(fin[' Discounts '], errors='coerce')

# %%
fin.head(10)
# Out:
#             Segment                   Country     Product   Discount Band   \
# 0        Government                    Canada   Carretera            None
# 1        Government                   Germany   Carretera            None
# 2         Midmarket                    France   Carretera            None
# 3         Midmarket                   Germany   Carretera            None
# 4         Midmarket                    Mexico   Carretera            None
# 5        Government                   Germany   Carretera            None
# 6        Enterprise  United States of America   Carretera             Low
# 7  Channel Partners                   Germany   Carretera             Low
# 8    Small Business                    Mexico   Carretera             Low
# 9    Small Business  United States of America     Montana             Low
#
#    Units Sold   Manufacturing Price   Sale Price     Gross Sales   \
# 0   $1,618.50                 $3.00       $20.00      $32,370.00
# ...

# %%
fin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Segment                30 non-null     object
#  1   Country                30 non-null     object
#  2    Product               30 non-null     object
#  3    Discount Band         30 non-null     object
#  4    Units Sold            30 non-null     object
#  5    Manufacturing Price   30 non-null     object
#  6    Sale Price            30 non-null     object
#  7    Gross Sales           30 non-null     object
#  8    Discounts             30 non-null     object
#  9     Sales                30 non-null     object
#  10   COGS                  30 non-null     object
#  11   Profit                30 non-null     object
#  12  Date                   30 non-null     datetime64[ns]
#  13  Month Number           30 non-null     int64
# ...

# %%
# Date and time handling
fin['Date'] = pd.to_datetime(fin['Date'], format ='%d-%m-%Y')

# %%
fin['Date_Format'] = fin['Date'].dt.strftime('%d-%m-%Y')

# %%
fin.head(10)
# Out:
#             Segment                   Country     Product   Discount Band   \
# 0        Government                    Canada   Carretera            None
# 1        Government                   Germany   Carretera            None
# 2         Midmarket                    France   Carretera            None
# 3         Midmarket                   Germany   Carretera            None
# 4         Midmarket                    Mexico   Carretera            None
# 5        Government                   Germany   Carretera            None
# 6        Enterprise  United States of America   Carretera             Low
# 7  Channel Partners                   Germany   Carretera             Low
# 8    Small Business                    Mexico   Carretera             Low
# 9    Small Business  United States of America     Montana             Low
#
#    Units Sold   Manufacturing Price   Sale Price     Gross Sales   \
# 0   $1,618.50                 $3.00       $20.00      $32,370.00
# ...

# %%
fin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Segment                30 non-null     object
#  1   Country                30 non-null     object
#  2    Product               30 non-null     object
#  3    Discount Band         30 non-null     object
#  4    Units Sold            30 non-null     object
#  5    Manufacturing Price   30 non-null     object
#  6    Sale Price            30 non-null     object
#  7    Gross Sales           30 non-null     object
#  8    Discounts             30 non-null     object
#  9     Sales                30 non-null     object
#  10   COGS                  30 non-null     object
#  11   Profit                30 non-null     object
#  12  Date                   30 non-null     datetime64[ns]
#  13  Month Number           30 non-null     int64
# ...

# %%
fin['Date'] = fin['Date'].dt.strftime('%d-%m-%Y')

# %%
fin.head(10)
# Out:
#             Segment                   Country     Product   Discount Band   \
# 0        Government                    Canada   Carretera            None
# 1        Government                   Germany   Carretera            None
# 2         Midmarket                    France   Carretera            None
# 3         Midmarket                   Germany   Carretera            None
# 4         Midmarket                    Mexico   Carretera            None
# 5        Government                   Germany   Carretera            None
# 6        Enterprise  United States of America   Carretera             Low
# 7  Channel Partners                   Germany   Carretera             Low
# 8    Small Business                    Mexico   Carretera             Low
# 9    Small Business  United States of America     Montana             Low
#
#    Units Sold   Manufacturing Price   Sale Price     Gross Sales   \
# 0   $1,618.50                 $3.00       $20.00      $32,370.00
# ...

# %%
fin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Segment                30 non-null     object
#  1   Country                30 non-null     object
#  2    Product               30 non-null     object
#  3    Discount Band         30 non-null     object
#  4    Units Sold            30 non-null     object
#  5    Manufacturing Price   30 non-null     object
#  6    Sale Price            30 non-null     object
#  7    Gross Sales           30 non-null     object
#  8    Discounts             30 non-null     object
#  9     Sales                30 non-null     object
#  10   COGS                  30 non-null     object
#  11   Profit                30 non-null     object
#  12  Date                   30 non-null     object
#  13  Month Number           30 non-null     int64
# ...

# %%
# fin['year'] = fin['date'].dt.year  
# fin['Month_Number'] = fin['date'].dt.month  
# fin['Day'] = fin['date'].dt.day
